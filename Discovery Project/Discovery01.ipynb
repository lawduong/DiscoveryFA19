# %% [markdown]
# ## Achievement Gap of Berkeley

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import zipfile

# %%
test_data = pd.read_csv("data/berkeley_2018.txt", index_col=0)
test_data.head()

# %%
data = test_data.drop(["District Code", "Filler", "Test Year", "Total Tested At Entity Level", "Total Tested with Scores", "CAASPP Reported Enrollment"], axis= 1)

# %%
male_data = data[test_data["Subgroup ID"] == 3]
female_data = data[test_data["Subgroup ID"] == 4]
male_data[["Students Tested", "School Code"]].sort_values(by="Students Tested", ascending=True)
# Out:
#             Students Tested  School Code
# County Code
# 1                         *       161143
# 1                         *       161143
# 1                         *       161143
# 1                         *       161143
# 1                         *       161143
# 1                         *       161143
# 1                         *       134924
# 1                         *       134924
# 1                         *       134924
# 1                         *       134924
# 1                         *       161143
# 1                         *       161143
# 1                         *       161143
# 1                         *       161143
# 1                         *       161143
# 1                         *       161143
# 1                       105      6090310
# 1                       105      6090310
# 1                       106      6097729
# 1                       106      6090252
# 1                       106      6090252
# ...
